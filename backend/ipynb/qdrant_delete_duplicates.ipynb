# %%
from qdrant_client import QdrantClient
from collections import defaultdict
import os
from dotenv import load_dotenv

# Load environment variables
load_dotenv()

# Connect to Qdrant Cloud
client = QdrantClient(
    url=os.getenv("QDRANT_URL"),
    api_key=os.getenv("QDRANT_API_KEY")
)

# Get list of all collections
collections = client.get_collections().collections

for collection in collections:
    collection_name = collection.name
    print(f"\nProcessing collection: {collection_name}")
    
    # Scroll through all points in collection
    points = client.scroll(
        collection_name=collection_name,
        with_payload=True,
        with_vectors=False
    )[0]
    
    # Track points by their filename
    seen_points = defaultdict(list)
    
    # Group points by filename
    for point in points:
        if 'filename' in point.payload:  # Check if filename exists in payload
            filename = point.payload['filename']
            seen_points[filename].append(point.id)
            if len(seen_points[filename]) > 1:  # Print when we find a duplicate
                print(f"Found duplicate for filename: {filename}")
    
    # Find and delete duplicates
    points_to_delete = []
    for filename_group in seen_points.values():
        if len(filename_group) > 1:
            # Keep the first occurrence, delete the rest
            points_to_delete.extend(filename_group[1:])
    
    # Delete duplicate points
    if points_to_delete:
        client.delete(
            collection_name=collection_name,
            points_selector=points_to_delete
        )
        print(f"Deleted {len(points_to_delete)} duplicates from {collection_name}")
        print(f"These had identical filenames.")
    else:
        print(f"No duplicates found in {collection_name}")
# Out:
# Processing collection: personality
# No duplicates found in personality
#
# Processing collection: storyteller
# No duplicates found in storyteller

# %%
from qdrant_client import QdrantClient
import os
from dotenv import load_dotenv
from collections import defaultdict

# Load environment variables
load_dotenv()

# Connect to Qdrant Cloud
client = QdrantClient(
    url=os.getenv("QDRANT_URL"),
    api_key=os.getenv("QDRANT_API_KEY")
)

# Get list of all collections
collections = client.get_collections().collections

for collection in collections:
    collection_name = collection.name
    print(f"\nAnalyzing collection: {collection_name}")
    
    # Scroll through all points in collection
    points = client.scroll(
        collection_name=collection_name,
        with_payload=True,
        with_vectors=False
    )[0]
    
    # Track unique filenames
    unique_filenames = set()
    total_points = 0
    
    # Count points and unique filenames
    for point in points:
        total_points += 1
        if 'filename' in point.payload:
            unique_filenames.add(point.payload['filename'])
    
    print(f"Total points in collection: {total_points}")
    print(f"Unique filenames: {len(unique_filenames)}")
    print(f"Potential duplicates: {total_points - len(unique_filenames)}")
# Out:
# Analyzing collection: personality
# Total points in collection: 10
# Unique filenames: 10
# Potential duplicates: 0
#
# Analyzing collection: storyteller
# Total points in collection: 10
# Unique filenames: 10
# Potential duplicates: 0

# %%
from qdrant_client import QdrantClient
import os
from dotenv import load_dotenv
from collections import defaultdict

# Load environment variables
load_dotenv()

# Connect to Qdrant Cloud
client = QdrantClient(
    url=os.getenv("QDRANT_URL"),
    api_key=os.getenv("QDRANT_API_KEY")
)

# Get list of all collections
collections = client.get_collections().collections

for collection in collections:
    collection_name = collection.name
    print(f"\nProcessing collection: {collection_name}")
    
    # Track points by their filename
    seen_points = defaultdict(list)
    
    # Scroll through all points with pagination
    offset = None
    while True:
        batch, offset = client.scroll(
            collection_name=collection_name,
            with_payload=True,
            with_vectors=False,
            offset=offset
        )
        
        # Group points by filename in this batch
        for point in batch:
            if 'filename' in point.payload:
                filename = point.payload['filename']
                seen_points[filename].append(point.id)
                if len(seen_points[filename]) > 1:
                    print(f"Found duplicate for filename: {filename}")
        
        # If no more offset, we've reached the end
        if offset is None:
            break
    
    # Find and delete duplicates
    points_to_delete = []
    for filename_group in seen_points.values():
        if len(filename_group) > 1:
            # Keep the first occurrence, delete the rest
            points_to_delete.extend(filename_group[1:])
    
    # Delete duplicate points
    if points_to_delete:
        print(f"Found {len(points_to_delete)} duplicates to delete")
        client.delete(
            collection_name=collection_name,
            points_selector=points_to_delete
        )
        print(f"Successfully deleted {len(points_to_delete)} duplicates from {collection_name}")
    else:
        print(f"No duplicates found in {collection_name}")
# Out:
# Processing collection: personality
# Found duplicate for filename: resume_1103.txt
# Found duplicate for filename: resume_1197.txt
# Found duplicate for filename: resume_1323.txt
# Found duplicate for filename: resume_1353.txt
# Found duplicate for filename: resume_105.txt
# Found duplicate for filename: resume_1086.txt
# Found duplicate for filename: resume_1344.txt
# Found duplicate for filename: resume_1163.txt
# Found duplicate for filename: resume_1071.txt
# Found duplicate for filename: resume_1007.txt
# Found duplicate for filename: resume_1393.txt
# Found duplicate for filename: resume_1116.txt
# Found duplicate for filename: resume_1216.txt
# Found duplicate for filename: resume_1280.txt
# Found duplicate for filename: resume_1324.txt
# Found duplicate for filename: resume_1282.txt
# Found duplicate for filename: resume_1235.txt
# Found duplicate for filename: resume_1074.txt
# Found duplicate for filename: resume_1285.txt
# Found duplicate for filename: resume_1015.txt
# Found duplicate for filename: resume_1178.txt
# Found duplicate for filename: resume_1223.txt
# Found duplicate for filename: resume_1253.txt
# Found duplicate for filename: resume_1045.txt
# Found duplicate for filename: resume_1287.txt
# Found duplicate for filename: resume_1042.txt
# Found duplicate for filename: resume_1192.txt
# Found duplicate for filename: resume_1330.txt
# Found duplicate for filename: resume_1129.txt
# Found duplicate for filename: resume_1206.txt
# Found duplicate for filename: resume_1308.txt
# Found duplicate for filename: resume_1173.txt
# Found duplicate for filename: resume_1190.txt
# Found duplicate for filename: resume_1209.txt
# Found duplicate for filename: resume_1151.txt
# Found duplicate for filename: resume_0.txt
# Found duplicate for filename: resume_1338.txt
# Found duplicate for filename: resume_1229.txt
# Found duplicate for filename: resume_1034.txt
# Found duplicate for filename: resume_1019.txt
# Found duplicate for filename: resume_116.txt
# Found duplicate for filename: resume_1135.txt
# Found duplicate for filename: resume_1249.txt
# Found duplicate for filename: resume_1248.txt
# Found duplicate for filename: resume_1297.txt
# Found duplicate for filename: resume_1281.txt
# Found duplicate for filename: resume_1277.txt
# Found duplicate for filename: resume_120.txt
# Found duplicate for filename: resume_1094.txt
# Found duplicate for filename: resume_1112.txt
# Found duplicate for filename: resume_1257.txt
# Found duplicate for filename: resume_139.txt
# Found duplicate for filename: resume_1061.txt
# Found duplicate for filename: resume_1134.txt
# Found duplicate for filename: resume_1384.txt
# Found duplicate for filename: resume_1389.txt
# Found duplicate for filename: resume_1142.txt
# Found duplicate for filename: resume_1311.txt
# Found duplicate for filename: resume_1392.txt
# Found duplicate for filename: resume_1148.txt
# Found duplicate for filename: resume_1214.txt
# Found duplicate for filename: resume_114.txt
# Found duplicate for filename: resume_1023.txt
# Found duplicate for filename: resume_1027.txt
# Found duplicate for filename: resume_1292.txt
# Found duplicate for filename: resume_1327.txt
# Found duplicate for filename: resume_109.txt
# Found duplicate for filename: resume_137.txt
# Found duplicate for filename: resume_1.txt
# Found duplicate for filename: resume_1293.txt
# Found duplicate for filename: resume_1372.txt
# Found duplicate for filename: resume_1299.txt
# Found duplicate for filename: resume_1395.txt
# Found duplicate for filename: resume_1225.txt
# Found duplicate for filename: resume_1037.txt
# Found duplicate for filename: resume_1036.txt
# Found duplicate for filename: resume_1204.txt
# Found duplicate for filename: resume_1199.txt
# Found duplicate for filename: resume_1159.txt
# Found duplicate for filename: resume_1364.txt
# Found duplicate for filename: resume_1171.txt
# Found duplicate for filename: resume_1092.txt
# Found duplicate for filename: resume_1260.txt
# Found duplicate for filename: resume_1296.txt
# Found duplicate for filename: resume_1002.txt
# Found duplicate for filename: resume_1399.txt
# Found duplicate for filename: resume_1167.txt
# Found duplicate for filename: resume_1004.txt
# Found duplicate for filename: resume_1351.txt
# Found duplicate for filename: resume_1162.txt
# Found duplicate for filename: resume_1078.txt
# Found duplicate for filename: resume_1355.txt
# Found duplicate for filename: resume_1001.txt
# Found duplicate for filename: resume_1275.txt
# Found duplicate for filename: resume_1194.txt
# Found duplicate for filename: resume_1201.txt
# Found duplicate for filename: resume_1145.txt
# Found duplicate for filename: resume_1131.txt
# Found duplicate for filename: resume_1006.txt
# Found duplicate for filename: resume_1268.txt
# Found duplicate for filename: resume_1101.txt
# Found duplicate for filename: resume_1189.txt
# Found duplicate for filename: resume_1220.txt
# Found duplicate for filename: resume_1126.txt
# Found duplicate for filename: resume_100.txt
# Found duplicate for filename: resume_1370.txt
# Found duplicate for filename: resume_1251.txt
# Found duplicate for filename: resume_1062.txt
# Found duplicate for filename: resume_1240.txt
# Found duplicate for filename: resume_1041.txt
# Found duplicate for filename: resume_1065.txt
# Found duplicate for filename: resume_1022.txt
# Found duplicate for filename: resume_1115.txt
# Found duplicate for filename: resume_1343.txt
# Found duplicate for filename: resume_1047.txt
# Found duplicate for filename: resume_1108.txt
# Found duplicate for filename: resume_13.txt
# Found duplicate for filename: resume_1048.txt
# Found duplicate for filename: resume_1239.txt
# Found duplicate for filename: resume_1222.txt
# Found duplicate for filename: resume_1348.txt
# Found duplicate for filename: resume_1024.txt
# Found duplicate for filename: resume_1341.txt
# Found duplicate for filename: resume_1139.txt
# Found duplicate for filename: resume_1005.txt
# Found duplicate for filename: resume_1358.txt
# Found duplicate for filename: resume_1102.txt
# Found duplicate for filename: resume_1346.txt
# Found duplicate for filename: resume_1332.txt
# Found duplicate for filename: resume_1215.txt
# Found duplicate for filename: resume_1191.txt
# Found duplicate for filename: resume_1060.txt
# Found duplicate for filename: resume_104.txt
# Found duplicate for filename: resume_1302.txt
# Found duplicate for filename: resume_1203.txt
# Found duplicate for filename: resume_1322.txt
# Found duplicate for filename: resume_1181.txt
# Found duplicate for filename: resume_1038.txt
# Found duplicate for filename: resume_1176.txt
# Found duplicate for filename: resume_1261.txt
# Found duplicate for filename: resume_1029.txt
# Found duplicate for filename: resume_1153.txt
# Found duplicate for filename: resume_1165.txt
# Found duplicate for filename: resume_1340.txt
# Found duplicate for filename: resume_1347.txt
# Found duplicate for filename: resume_1271.txt
# Found duplicate for filename: resume_1295.txt
# Found duplicate for filename: resume_1325.txt
# Found duplicate for filename: resume_133.txt
# Found duplicate for filename: resume_1184.txt
# Found duplicate for filename: resume_1110.txt
# Found duplicate for filename: resume_1352.txt
# Found duplicate for filename: resume_1334.txt
# Found duplicate for filename: resume_1100.txt
# Found duplicate for filename: resume_1221.txt
# Found duplicate for filename: resume_1245.txt
# Found duplicate for filename: resume_1188.txt
# Found duplicate for filename: resume_1333.txt
# Found duplicate for filename: resume_1207.txt
# Found duplicate for filename: resume_1200.txt
# Found duplicate for filename: resume_1278.txt
# Found duplicate for filename: resume_1152.txt
# Found duplicate for filename: resume_132.txt
# Found duplicate for filename: resume_1345.txt
# Found duplicate for filename: resume_124.txt
# Found duplicate for filename: resume_117.txt
# Found duplicate for filename: resume_1075.txt
# Found duplicate for filename: resume_1350.txt
# Found duplicate for filename: resume_1256.txt
# Found duplicate for filename: resume_1288.txt
# Found duplicate for filename: resume_138.txt
# Found duplicate for filename: resume_1283.txt
# Found duplicate for filename: resume_1342.txt
# Found duplicate for filename: resume_107.txt
# Found duplicate for filename: resume_1267.txt
# Found duplicate for filename: resume_1359.txt
# Found duplicate for filename: resume_1236.txt
# Found duplicate for filename: resume_1365.txt
# Found duplicate for filename: resume_1157.txt
# Found duplicate for filename: resume_1182.txt
# Found duplicate for filename: resume_1016.txt
# Found duplicate for filename: resume_1059.txt
# Found duplicate for filename: resume_111.txt
# Found duplicate for filename: resume_1054.txt
# Found duplicate for filename: resume_1394.txt
# Found duplicate for filename: resume_123.txt
# Found duplicate for filename: resume_1335.txt
# Found duplicate for filename: resume_1124.txt
# Found duplicate for filename: resume_1140.txt
# Found duplicate for filename: resume_1303.txt
# Found duplicate for filename: resume_1161.txt
# Found duplicate for filename: resume_1233.txt
# Found duplicate for filename: resume_1091.txt
# Found duplicate for filename: resume_1154.txt
# Found duplicate for filename: resume_121.txt
# Found duplicate for filename: resume_1258.txt
# Found duplicate for filename: resume_1371.txt
# Found duplicate for filename: resume_1316.txt
# Found duplicate for filename: resume_1349.txt
# Found duplicate for filename: resume_127.txt
# Found duplicate for filename: resume_1052.txt
# Found duplicate for filename: resume_1262.txt
# Found duplicate for filename: resume_130.txt
# Found duplicate for filename: resume_1336.txt
# Found duplicate for filename: resume_1070.txt
# Found duplicate for filename: resume_106.txt
# Found duplicate for filename: resume_1111.txt
# Found duplicate for filename: resume_1397.txt
# Found duplicate for filename: resume_1250.txt
# Found duplicate for filename: resume_1265.txt
# Found duplicate for filename: resume_126.txt
# Found duplicate for filename: resume_1130.txt
# Found duplicate for filename: resume_1049.txt
# Found duplicate for filename: resume_1388.txt
# Found duplicate for filename: resume_1137.txt
# Found duplicate for filename: resume_1386.txt
# Found duplicate for filename: resume_119.txt
# Found duplicate for filename: resume_1290.txt
# Found duplicate for filename: resume_1320.txt
# Found duplicate for filename: resume_1088.txt
# Found duplicate for filename: resume_1030.txt
# Found duplicate for filename: resume_102.txt
# Found duplicate for filename: resume_101.txt
# Found duplicate for filename: resume_1317.txt
# Found duplicate for filename: resume_1366.txt
# Found duplicate for filename: resume_108.txt
# Found duplicate for filename: resume_1172.txt
# Found duplicate for filename: resume_1218.txt
# Found duplicate for filename: resume_1156.txt
# Found duplicate for filename: resume_1244.txt
# Found duplicate for filename: resume_135.txt
# Found duplicate for filename: resume_1377.txt
# Found duplicate for filename: resume_1321.txt
# Found duplicate for filename: resume_1174.txt
# Found duplicate for filename: resume_1098.txt
# Found duplicate for filename: resume_1149.txt
# Found duplicate for filename: resume_1026.txt
# Found duplicate for filename: resume_1017.txt
# Found duplicate for filename: resume_1081.txt
# Found duplicate for filename: resume_1210.txt
# Found duplicate for filename: resume_12.txt
# Found duplicate for filename: resume_11.txt
# Found duplicate for filename: resume_1056.txt
# Found duplicate for filename: resume_1123.txt
# Found duplicate for filename: resume_1387.txt
# Found duplicate for filename: resume_1279.txt
# Found duplicate for filename: resume_1089.txt
# Found duplicate for filename: resume_1039.txt
# Found duplicate for filename: resume_1396.txt
# Found duplicate for filename: resume_1150.txt
# Found duplicate for filename: resume_1301.txt
# Found duplicate for filename: resume_1381.txt
# Found duplicate for filename: resume_1014.txt
# Found duplicate for filename: resume_125.txt
# Found duplicate for filename: resume_1083.txt
# Found duplicate for filename: resume_1069.txt
# Found duplicate for filename: resume_1306.txt
# Found duplicate for filename: resume_1046.txt
# Found duplicate for filename: resume_1390.txt
# Found duplicate for filename: resume_1264.txt
# Found duplicate for filename: resume_1357.txt
# Found duplicate for filename: resume_1360.txt
# Found duplicate for filename: resume_1328.txt
# Found duplicate for filename: resume_113.txt
# Found duplicate for filename: resume_1032.txt
# Found duplicate for filename: resume_1051.txt
# Found duplicate for filename: resume_1031.txt
# Found duplicate for filename: resume_1202.txt
# Found duplicate for filename: resume_1175.txt
# Found duplicate for filename: resume_1146.txt
# Found duplicate for filename: resume_1013.txt
# Found duplicate for filename: resume_1310.txt
# Found duplicate for filename: resume_1270.txt
# Found duplicate for filename: resume_1068.txt
# Found duplicate for filename: resume_1212.txt
# Found duplicate for filename: resume_1107.txt
# Found duplicate for filename: resume_1363.txt
# Found duplicate for filename: resume_1238.txt
# Found duplicate for filename: resume_1084.txt
# Found duplicate for filename: resume_1097.txt
# Found duplicate for filename: resume_1284.txt
# Found duplicate for filename: resume_1168.txt
# Found duplicate for filename: resume_1255.txt
# Found duplicate for filename: resume_1274.txt
# Found duplicate for filename: resume_1315.txt
# Found duplicate for filename: resume_1066.txt
# Found duplicate for filename: resume_1120.txt
# Found duplicate for filename: resume_1044.txt
# Found duplicate for filename: resume_1339.txt
# Found duplicate for filename: resume_1166.txt
# Found duplicate for filename: resume_1109.txt
# Found duplicate for filename: resume_14.txt
# Found duplicate for filename: resume_1122.txt
# Found duplicate for filename: resume_1082.txt
# Found duplicate for filename: resume_1104.txt
# Found duplicate for filename: resume_1307.txt
# Found duplicate for filename: resume_1375.txt
# Found duplicate for filename: resume_1246.txt
# Found duplicate for filename: resume_1058.txt
# Found duplicate for filename: resume_1169.txt
# Found duplicate for filename: resume_1326.txt
# Found duplicate for filename: resume_1121.txt
# Found duplicate for filename: resume_1073.txt
# Found duplicate for filename: resume_1025.txt
# Found duplicate for filename: resume_1263.txt
# Found duplicate for filename: resume_1337.txt
# Found duplicate for filename: resume_1183.txt
# Found duplicate for filename: resume_1391.txt
# Found duplicate for filename: resume_1252.txt
# Found duplicate for filename: resume_1243.txt
# Found duplicate for filename: resume_1259.txt
# Found duplicate for filename: resume_1055.txt
# Found duplicate for filename: resume_115.txt
# Found duplicate for filename: resume_1133.txt
# Found duplicate for filename: resume_1376.txt
# Found duplicate for filename: resume_1118.txt
# Found duplicate for filename: resume_1180.txt
# Found duplicate for filename: resume_1193.txt
# Found duplicate for filename: resume_1224.txt
# Found duplicate for filename: resume_1043.txt
# Found duplicate for filename: resume_1185.txt
# Found duplicate for filename: resume_1247.txt
# Found duplicate for filename: resume_1319.txt
# Found duplicate for filename: resume_1009.txt
# Found duplicate for filename: resume_129.txt
# Found duplicate for filename: resume_1368.txt
# Found duplicate for filename: resume_1093.txt
# Found duplicate for filename: resume_1273.txt
# Found duplicate for filename: resume_1136.txt
# Found duplicate for filename: resume_1012.txt
# Found duplicate for filename: resume_1003.txt
# Found duplicate for filename: resume_1379.txt
# Found duplicate for filename: resume_1155.txt
# Found duplicate for filename: resume_1035.txt
# Found duplicate for filename: resume_1318.txt
# Found duplicate for filename: resume_1228.txt
# Found duplicate for filename: resume_1286.txt
# Found duplicate for filename: resume_1080.txt
# Found duplicate for filename: resume_1382.txt
# Found duplicate for filename: resume_1198.txt
# Found duplicate for filename: resume_1195.txt
# Found duplicate for filename: resume_1232.txt
# Found duplicate for filename: resume_1138.txt
# Found duplicate for filename: resume_1057.txt
# Found duplicate for filename: resume_1398.txt
# Found duplicate for filename: resume_1028.txt
# Found duplicate for filename: resume_1217.txt
# Found duplicate for filename: resume_1040.txt
# Found duplicate for filename: resume_103.txt
# Found duplicate for filename: resume_1158.txt
# Found duplicate for filename: resume_1374.txt
# Found duplicate for filename: resume_1072.txt
# Found duplicate for filename: resume_1373.txt
# Found duplicate for filename: resume_1008.txt
# Found duplicate for filename: resume_1010.txt
# Found duplicate for filename: resume_1314.txt
# Found duplicate for filename: resume_1147.txt
# Found duplicate for filename: resume_1213.txt
# Found duplicate for filename: resume_1067.txt
# Found duplicate for filename: resume_1237.txt
# Found duplicate for filename: resume_110.txt
# Found duplicate for filename: resume_1099.txt
# Found duplicate for filename: resume_1106.txt
# Found duplicate for filename: resume_1117.txt
# Found duplicate for filename: resume_1227.txt
# Found duplicate for filename: resume_1144.txt
# Found duplicate for filename: resume_128.txt
# Found duplicate for filename: resume_1141.txt
# Found duplicate for filename: resume_1113.txt
# Found duplicate for filename: resume_1354.txt
# Found duplicate for filename: resume_1367.txt
# Found duplicate for filename: resume_1064.txt
# Found duplicate for filename: resume_1269.txt
# Found duplicate for filename: resume_1361.txt
# Found duplicate for filename: resume_1205.txt
# Found duplicate for filename: resume_134.txt
# Found duplicate for filename: resume_1304.txt
# Found duplicate for filename: resume_1242.txt
# Found duplicate for filename: resume_1125.txt
# Found duplicate for filename: resume_1196.txt
# Found duplicate for filename: resume_1300.txt
# Found duplicate for filename: resume_1291.txt
# Found duplicate for filename: resume_122.txt
# Found duplicate for filename: resume_1313.txt
# Found duplicate for filename: resume_1312.txt
# Found duplicate for filename: resume_1085.txt
# Found duplicate for filename: resume_112.txt
# Found duplicate for filename: resume_1231.txt
# Found duplicate for filename: resume_1276.txt
# Found duplicate for filename: resume_1378.txt
# Found duplicate for filename: resume_1234.txt
# Found duplicate for filename: resume_1254.txt
# Found duplicate for filename: resume_1087.txt
# Found duplicate for filename: resume_1289.txt
# Found duplicate for filename: resume_1132.txt
# Found duplicate for filename: resume_1000.txt
# Found duplicate for filename: resume_1305.txt
# Found duplicate for filename: resume_1050.txt
# Found duplicate for filename: resume_1298.txt
# Found duplicate for filename: resume_1164.txt
# Found duplicate for filename: resume_1077.txt
# Found duplicate for filename: resume_1331.txt
# Found duplicate for filename: resume_1119.txt
# Found duplicate for filename: resume_1362.txt
# Found duplicate for filename: resume_1187.txt
# Found duplicate for filename: resume_1095.txt
# Found duplicate for filename: resume_1105.txt
# Found duplicate for filename: resume_1241.txt
# Found duplicate for filename: resume_1114.txt
# Found duplicate for filename: resume_10.txt
# Found duplicate for filename: resume_1011.txt
# Found duplicate for filename: resume_1018.txt
# Found duplicate for filename: resume_1179.txt
# Found duplicate for filename: resume_1309.txt
# Found duplicate for filename: resume_1053.txt
# Found duplicate for filename: resume_1063.txt
# Found duplicate for filename: resume_1208.txt
# Found duplicate for filename: resume_1356.txt
# Found duplicate for filename: resume_1294.txt
# Found duplicate for filename: resume_1380.txt
# Found duplicate for filename: resume_1033.txt
# Found duplicate for filename: resume_1143.txt
# Found duplicate for filename: resume_1219.txt
# Found duplicate for filename: resume_1096.txt
# Found duplicate for filename: resume_1186.txt
# Found duplicate for filename: resume_1369.txt
# Found duplicate for filename: resume_1226.txt
# Found duplicate for filename: resume_1177.txt
# Found duplicate for filename: resume_118.txt
# Found duplicate for filename: resume_1383.txt
# Found duplicate for filename: resume_1385.txt
# Found duplicate for filename: resume_1020.txt
# Found duplicate for filename: resume_1266.txt
# Found duplicate for filename: resume_136.txt
# Found duplicate for filename: resume_1076.txt
# Found duplicate for filename: resume_1127.txt
# Found duplicate for filename: resume_1272.txt
# Found duplicate for filename: resume_1090.txt
# Found duplicate for filename: resume_1211.txt
# Found duplicate for filename: resume_1230.txt
# Found duplicate for filename: resume_1079.txt
# Found duplicate for filename: resume_1160.txt
# Found duplicate for filename: resume_1128.txt
# Found duplicate for filename: resume_1170.txt
# Found duplicate for filename: resume_131.txt
# Found duplicate for filename: resume_1021.txt
# Found duplicate for filename: resume_1329.txt
# Found 447 duplicates to delete
# Successfully deleted 447 duplicates from personality
#
# Processing collection: storyteller
# Found duplicate for filename: resume_1381.txt
# Found duplicate for filename: resume_1171.txt
# Found duplicate for filename: resume_1114.txt
# Found duplicate for filename: resume_1210.txt
# Found duplicate for filename: resume_1036.txt
# Found duplicate for filename: resume_1034.txt
# Found duplicate for filename: resume_1225.txt
# Found duplicate for filename: resume_1228.txt
# Found duplicate for filename: resume_1091.txt
# Found duplicate for filename: resume_1206.txt
# Found duplicate for filename: resume_138.txt
# Found duplicate for filename: resume_1262.txt
# Found duplicate for filename: resume_1046.txt
# Found duplicate for filename: resume_1048.txt
# Found duplicate for filename: resume_1087.txt
# Found duplicate for filename: resume_1174.txt
# Found duplicate for filename: resume_1378.txt
# Found duplicate for filename: resume_1297.txt
# Found duplicate for filename: resume_1042.txt
# Found duplicate for filename: resume_1338.txt
# Found duplicate for filename: resume_1253.txt
# Found duplicate for filename: resume_1224.txt
# Found duplicate for filename: resume_1041.txt
# Found duplicate for filename: resume_131.txt
# Found duplicate for filename: resume_1157.txt
# Found duplicate for filename: resume_1387.txt
# Found duplicate for filename: resume_1305.txt
# Found duplicate for filename: resume_1362.txt
# Found duplicate for filename: resume_1049.txt
# Found duplicate for filename: resume_1267.txt
# Found duplicate for filename: resume_1372.txt
# Found duplicate for filename: resume_132.txt
# Found duplicate for filename: resume_1220.txt
# Found duplicate for filename: resume_1368.txt
# Found duplicate for filename: resume_1093.txt
# Found duplicate for filename: resume_1242.txt
# Found duplicate for filename: resume_109.txt
# Found duplicate for filename: resume_1109.txt
# Found duplicate for filename: resume_1316.txt
# Found duplicate for filename: resume_1353.txt
# Found duplicate for filename: resume_1318.txt
# Found duplicate for filename: resume_1150.txt
# Found duplicate for filename: resume_1155.txt
# Found duplicate for filename: resume_1232.txt
# Found duplicate for filename: resume_1251.txt
# Found duplicate for filename: resume_1090.txt
# Found duplicate for filename: resume_123.txt
# Found duplicate for filename: resume_1214.txt
# Found duplicate for filename: resume_1288.txt
# Found duplicate for filename: resume_1292.txt
# Found duplicate for filename: resume_1345.txt
# Found duplicate for filename: resume_1149.txt
# Found duplicate for filename: resume_1357.txt
# Found duplicate for filename: resume_1397.txt
# Found duplicate for filename: resume_1122.txt
# Found duplicate for filename: resume_1321.txt
# Found duplicate for filename: resume_1385.txt
# Found duplicate for filename: resume_1289.txt
# Found duplicate for filename: resume_1317.txt
# Found duplicate for filename: resume_1330.txt
# Found duplicate for filename: resume_1205.txt
# Found duplicate for filename: resume_1015.txt
# Found duplicate for filename: resume_125.txt
# Found duplicate for filename: resume_1222.txt
# Found duplicate for filename: resume_1069.txt
# Found duplicate for filename: resume_1201.txt
# Found duplicate for filename: resume_1001.txt
# Found duplicate for filename: resume_1197.txt
# Found duplicate for filename: resume_1281.txt
# Found duplicate for filename: resume_126.txt
# Found duplicate for filename: resume_1393.txt
# Found duplicate for filename: resume_1237.txt
# Found duplicate for filename: resume_1198.txt
# Found duplicate for filename: resume_1373.txt
# Found duplicate for filename: resume_1000.txt
# Found duplicate for filename: resume_1101.txt
# Found duplicate for filename: resume_1377.txt
# Found duplicate for filename: resume_1107.txt
# Found duplicate for filename: resume_105.txt
# Found duplicate for filename: resume_115.txt
# Found duplicate for filename: resume_1331.txt
# Found duplicate for filename: resume_108.txt
# Found duplicate for filename: resume_1062.txt
# Found duplicate for filename: resume_1052.txt
# Found duplicate for filename: resume_1061.txt
# Found duplicate for filename: resume_1395.txt
# Found duplicate for filename: resume_1071.txt
# Found duplicate for filename: resume_1384.txt
# Found duplicate for filename: resume_1249.txt
# Found duplicate for filename: resume_1152.txt
# Found duplicate for filename: resume_1179.txt
# Found duplicate for filename: resume_124.txt
# Found duplicate for filename: resume_1026.txt
# Found duplicate for filename: resume_1032.txt
# Found duplicate for filename: resume_1256.txt
# Found duplicate for filename: resume_1173.txt
# Found duplicate for filename: resume_1145.txt
# Found duplicate for filename: resume_1349.txt
# Found duplicate for filename: resume_1300.txt
# Found duplicate for filename: resume_1257.txt
# Found duplicate for filename: resume_1215.txt
# Found duplicate for filename: resume_1012.txt
# Found duplicate for filename: resume_1020.txt
# Found duplicate for filename: resume_1096.txt
# Found duplicate for filename: resume_1097.txt
# Found duplicate for filename: resume_1319.txt
# Found duplicate for filename: resume_1105.txt
# Found duplicate for filename: resume_1280.txt
# Found duplicate for filename: resume_1275.txt
# Found duplicate for filename: resume_1162.txt
# Found duplicate for filename: resume_1399.txt
# Found duplicate for filename: resume_1084.txt
# Found duplicate for filename: resume_1080.txt
# Found duplicate for filename: resume_1360.txt
# Found duplicate for filename: resume_1133.txt
# Found duplicate for filename: resume_1016.txt
# Found duplicate for filename: resume_1200.txt
# Found duplicate for filename: resume_1248.txt
# Found duplicate for filename: resume_1363.txt
# Found duplicate for filename: resume_1366.txt
# Found duplicate for filename: resume_1151.txt
# Found duplicate for filename: resume_1125.txt
# Found duplicate for filename: resume_1269.txt
# Found duplicate for filename: resume_1359.txt
# Found duplicate for filename: resume_1017.txt
# Found duplicate for filename: resume_1290.txt
# Found duplicate for filename: resume_1019.txt
# Found duplicate for filename: resume_1334.txt
# Found duplicate for filename: resume_1235.txt
# Found duplicate for filename: resume_1383.txt
# Found duplicate for filename: resume_1195.txt
# Found duplicate for filename: resume_1274.txt
# Found duplicate for filename: resume_1169.txt
# Found duplicate for filename: resume_1379.txt
# Found duplicate for filename: resume_1095.txt
# Found duplicate for filename: resume_1243.txt
# Found duplicate for filename: resume_135.txt
# Found duplicate for filename: resume_1294.txt
# Found duplicate for filename: resume_1287.txt
# Found duplicate for filename: resume_1088.txt
# Found duplicate for filename: resume_1218.txt
# Found duplicate for filename: resume_1291.txt
# Found duplicate for filename: resume_1230.txt
# Found duplicate for filename: resume_1284.txt
# Found duplicate for filename: resume_1167.txt
# Found duplicate for filename: resume_1212.txt
# Found duplicate for filename: resume_1303.txt
# Found duplicate for filename: resume_1278.txt
# Found duplicate for filename: resume_1299.txt
# Found duplicate for filename: resume_101.txt
# Found duplicate for filename: resume_1003.txt
# Found duplicate for filename: resume_1035.txt
# Found duplicate for filename: resume_1144.txt
# Found duplicate for filename: resume_1055.txt
# Found duplicate for filename: resume_1246.txt
# Found duplicate for filename: resume_1013.txt
# Found duplicate for filename: resume_1293.txt
# Found duplicate for filename: resume_1329.txt
# Found duplicate for filename: resume_1204.txt
# Found duplicate for filename: resume_1082.txt
# Found duplicate for filename: resume_128.txt
# Found duplicate for filename: resume_1391.txt
# Found duplicate for filename: resume_1079.txt
# Found duplicate for filename: resume_1108.txt
# Found duplicate for filename: resume_1029.txt
# Found duplicate for filename: resume_1075.txt
# Found duplicate for filename: resume_1211.txt
# Found duplicate for filename: resume_139.txt
# Found duplicate for filename: resume_112.txt
# Found duplicate for filename: resume_1315.txt
# Found duplicate for filename: resume_1355.txt
# Found duplicate for filename: resume_1361.txt
# Found duplicate for filename: resume_1081.txt
# Found duplicate for filename: resume_1143.txt
# Found duplicate for filename: resume_1134.txt
# Found duplicate for filename: resume_1245.txt
# Found duplicate for filename: resume_111.txt
# Found duplicate for filename: resume_1194.txt
# Found duplicate for filename: resume_1276.txt
# Found duplicate for filename: resume_1339.txt
# Found duplicate for filename: resume_1371.txt
# Found duplicate for filename: resume_1094.txt
# Found duplicate for filename: resume_1028.txt
# Found duplicate for filename: resume_1077.txt
# Found duplicate for filename: resume_1216.txt
# Found duplicate for filename: resume_1004.txt
# Found duplicate for filename: resume_1128.txt
# Found duplicate for filename: resume_1283.txt
# Found duplicate for filename: resume_1341.txt
# Found duplicate for filename: resume_1311.txt
# Found duplicate for filename: resume_1060.txt
# Found duplicate for filename: resume_114.txt
# Found duplicate for filename: resume_1086.txt
# Found duplicate for filename: resume_1382.txt
# Found duplicate for filename: resume_1057.txt
# Found duplicate for filename: resume_1332.txt
# Found duplicate for filename: resume_1018.txt
# Found duplicate for filename: resume_1333.txt
# Found duplicate for filename: resume_1025.txt
# Found duplicate for filename: resume_107.txt
# Found duplicate for filename: resume_1244.txt
# Found duplicate for filename: resume_1203.txt
# Found duplicate for filename: resume_117.txt
# Found duplicate for filename: resume_1103.txt
# Found duplicate for filename: resume_1166.txt
# Found duplicate for filename: resume_1141.txt
# Found duplicate for filename: resume_110.txt
# Found duplicate for filename: resume_1221.txt
# Found duplicate for filename: resume_0.txt
# Found duplicate for filename: resume_1272.txt
# Found duplicate for filename: resume_1116.txt
# Found duplicate for filename: resume_1014.txt
# Found duplicate for filename: resume_1375.txt
# Found duplicate for filename: resume_1327.txt
# Found duplicate for filename: resume_11.txt
# Found duplicate for filename: resume_1104.txt
# Found duplicate for filename: resume_1039.txt
# Found duplicate for filename: resume_1040.txt
# Found duplicate for filename: resume_1160.txt
# Found duplicate for filename: resume_1310.txt
# Found duplicate for filename: resume_1231.txt
# Found duplicate for filename: resume_1347.txt
# Found duplicate for filename: resume_1192.txt
# Found duplicate for filename: resume_1159.txt
# Found duplicate for filename: resume_1022.txt
# Found duplicate for filename: resume_1066.txt
# Found duplicate for filename: resume_1078.txt
# Found duplicate for filename: resume_1191.txt
# Found duplicate for filename: resume_1056.txt
# Found duplicate for filename: resume_1301.txt
# Found duplicate for filename: resume_1350.txt
# Found duplicate for filename: resume_1241.txt
# Found duplicate for filename: resume_1024.txt
# Found duplicate for filename: resume_1354.txt
# Found duplicate for filename: resume_1277.txt
# Found duplicate for filename: resume_1258.txt
# Found duplicate for filename: resume_1324.txt
# Found duplicate for filename: resume_1367.txt
# Found duplicate for filename: resume_122.txt
# Found duplicate for filename: resume_1390.txt
# Found duplicate for filename: resume_1226.txt
# Found duplicate for filename: resume_1119.txt
# Found duplicate for filename: resume_1110.txt
# Found duplicate for filename: resume_134.txt
# Found duplicate for filename: resume_1309.txt
# Found duplicate for filename: resume_1346.txt
# Found duplicate for filename: resume_127.txt
# Found duplicate for filename: resume_1175.txt
# Found duplicate for filename: resume_1356.txt
# Found duplicate for filename: resume_1068.txt
# Found duplicate for filename: resume_1161.txt
# Found duplicate for filename: resume_103.txt
# Found duplicate for filename: resume_1307.txt
# Found duplicate for filename: resume_1351.txt
# Found duplicate for filename: resume_1370.txt
# Found duplicate for filename: resume_1023.txt
# Found duplicate for filename: resume_1298.txt
# Found duplicate for filename: resume_1239.txt
# Found duplicate for filename: resume_1240.txt
# Found duplicate for filename: resume_119.txt
# Found duplicate for filename: resume_1396.txt
# Found duplicate for filename: resume_1006.txt
# Found duplicate for filename: resume_1063.txt
# Found duplicate for filename: resume_1092.txt
# Found duplicate for filename: resume_1165.txt
# Found duplicate for filename: resume_1193.txt
# Found duplicate for filename: resume_1121.txt
# Found duplicate for filename: resume_137.txt
# Found duplicate for filename: resume_1181.txt
# Found duplicate for filename: resume_1135.txt
# Found duplicate for filename: resume_1185.txt
# Found duplicate for filename: resume_1147.txt
# Found duplicate for filename: resume_121.txt
# Found duplicate for filename: resume_1264.txt
# Found duplicate for filename: resume_1132.txt
# Found duplicate for filename: resume_1365.txt
# Found duplicate for filename: resume_1286.txt
# Found duplicate for filename: resume_1342.txt
# Found duplicate for filename: resume_1126.txt
# Found duplicate for filename: resume_133.txt
# Found duplicate for filename: resume_1398.txt
# Found duplicate for filename: resume_1336.txt
# Found duplicate for filename: resume_1027.txt
# Found duplicate for filename: resume_1386.txt
# Found duplicate for filename: resume_1394.txt
# Found duplicate for filename: resume_1229.txt
# Found duplicate for filename: resume_1308.txt
# Found duplicate for filename: resume_1009.txt
# Found duplicate for filename: resume_1008.txt
# Found duplicate for filename: resume_10.txt
# Found duplicate for filename: resume_1044.txt
# Found duplicate for filename: resume_1302.txt
# Found duplicate for filename: resume_1328.txt
# Found duplicate for filename: resume_1064.txt
# Found duplicate for filename: resume_1236.txt
# Found duplicate for filename: resume_1392.txt
# Found duplicate for filename: resume_1146.txt
# Found duplicate for filename: resume_100.txt
# Found duplicate for filename: resume_1156.txt
# Found duplicate for filename: resume_1182.txt
# Found duplicate for filename: resume_1124.txt
# Found duplicate for filename: resume_1011.txt
# Found duplicate for filename: resume_1295.txt
# Found duplicate for filename: resume_1070.txt
# Found duplicate for filename: resume_1153.txt
# Found duplicate for filename: resume_1021.txt
# Found duplicate for filename: resume_1184.txt
# Found duplicate for filename: resume_1209.txt
# Found duplicate for filename: resume_1312.txt
# Found duplicate for filename: resume_1123.txt
# Found duplicate for filename: resume_1219.txt
# Found duplicate for filename: resume_1115.txt
# Found duplicate for filename: resume_1389.txt
# Found duplicate for filename: resume_1178.txt
# Found duplicate for filename: resume_1072.txt
# Found duplicate for filename: resume_1047.txt
# Found duplicate for filename: resume_1142.txt
# Found duplicate for filename: resume_1260.txt
# Found duplicate for filename: resume_1170.txt
# Found duplicate for filename: resume_1313.txt
# Found duplicate for filename: resume_1199.txt
# Found duplicate for filename: resume_1304.txt
# Found duplicate for filename: resume_1233.txt
# Found duplicate for filename: resume_129.txt
# Found duplicate for filename: resume_1306.txt
# Found duplicate for filename: resume_1099.txt
# Found duplicate for filename: resume_1163.txt
# Found duplicate for filename: resume_1118.txt
# Found duplicate for filename: resume_1139.txt
# Found duplicate for filename: resume_1252.txt
# Found duplicate for filename: resume_1270.txt
# Found duplicate for filename: resume_1196.txt
# Found duplicate for filename: resume_1188.txt
# Found duplicate for filename: resume_1296.txt
# Found duplicate for filename: resume_116.txt
# Found duplicate for filename: resume_1154.txt
# Found duplicate for filename: resume_1186.txt
# Found duplicate for filename: resume_1177.txt
# Found duplicate for filename: resume_1376.txt
# Found duplicate for filename: resume_1323.txt
# Found duplicate for filename: resume_1358.txt
# Found duplicate for filename: resume_1111.txt
# Found duplicate for filename: resume_1183.txt
# Found duplicate for filename: resume_1352.txt
# Found duplicate for filename: resume_1263.txt
# Found duplicate for filename: resume_1364.txt
# Found duplicate for filename: resume_1058.txt
# Found duplicate for filename: resume_1340.txt
# Found duplicate for filename: resume_1337.txt
# Found duplicate for filename: resume_1320.txt
# Found duplicate for filename: resume_1227.txt
# Found duplicate for filename: resume_1098.txt
# Found duplicate for filename: resume_1180.txt
# Found duplicate for filename: resume_1176.txt
# Found duplicate for filename: resume_1037.txt
# Found duplicate for filename: resume_1045.txt
# Found duplicate for filename: resume_1130.txt
# Found duplicate for filename: resume_1102.txt
# Found duplicate for filename: resume_1137.txt
# Found duplicate for filename: resume_1344.txt
# Found duplicate for filename: resume_1051.txt
# Found duplicate for filename: resume_1074.txt
# Found duplicate for filename: resume_1127.txt
# Found duplicate for filename: resume_1254.txt
# Found duplicate for filename: resume_1043.txt
# Found duplicate for filename: resume_1261.txt
# Found duplicate for filename: resume_1073.txt
# Found duplicate for filename: resume_113.txt
# Found duplicate for filename: resume_1265.txt
# Found duplicate for filename: resume_1279.txt
# Found duplicate for filename: resume_13.txt
# Found duplicate for filename: resume_1369.txt
# Found duplicate for filename: resume_1136.txt
# Found duplicate for filename: resume_102.txt
# Found duplicate for filename: resume_1335.txt
# Found duplicate for filename: resume_1238.txt
# Found duplicate for filename: resume_1282.txt
# Found duplicate for filename: resume_1273.txt
# Found duplicate for filename: resume_1113.txt
# Found duplicate for filename: resume_1255.txt
# Found duplicate for filename: resume_1374.txt
# Found duplicate for filename: resume_1250.txt
# Found duplicate for filename: resume_1010.txt
# Found duplicate for filename: resume_136.txt
# Found duplicate for filename: resume_1140.txt
# Found duplicate for filename: resume_1085.txt
# Found duplicate for filename: resume_1187.txt
# Found duplicate for filename: resume_1223.txt
# Found duplicate for filename: resume_1033.txt
# Found duplicate for filename: resume_1089.txt
# Found duplicate for filename: resume_1247.txt
# Found duplicate for filename: resume_1059.txt
# Found duplicate for filename: resume_1259.txt
# Found duplicate for filename: resume_120.txt
# Found duplicate for filename: resume_1322.txt
# Found duplicate for filename: resume_1131.txt
# Found duplicate for filename: resume_1065.txt
# Found duplicate for filename: resume_1268.txt
# Found duplicate for filename: resume_12.txt
# Found duplicate for filename: resume_1380.txt
# Found duplicate for filename: resume_1.txt
# Found duplicate for filename: resume_1050.txt
# Found duplicate for filename: resume_1120.txt
# Found duplicate for filename: resume_1100.txt
# Found duplicate for filename: resume_1053.txt
# Found duplicate for filename: resume_1325.txt
# Found duplicate for filename: resume_1202.txt
# Found duplicate for filename: resume_1030.txt
# Found duplicate for filename: resume_1217.txt
# Found duplicate for filename: resume_1266.txt
# Found duplicate for filename: resume_1208.txt
# Found duplicate for filename: resume_1158.txt
# Found duplicate for filename: resume_1207.txt
# Found duplicate for filename: resume_1326.txt
# Found duplicate for filename: resume_1038.txt
# Found duplicate for filename: resume_1285.txt
# Found duplicate for filename: resume_1271.txt
# Found duplicate for filename: resume_1129.txt
# Found duplicate for filename: resume_1117.txt
# Found duplicate for filename: resume_130.txt
# Found duplicate for filename: resume_1213.txt
# Found duplicate for filename: resume_14.txt
# Found duplicate for filename: resume_1343.txt
# Found duplicate for filename: resume_1148.txt
# Found duplicate for filename: resume_1005.txt
# Found duplicate for filename: resume_1348.txt
# Found duplicate for filename: resume_1190.txt
# Found duplicate for filename: resume_1007.txt
# Found duplicate for filename: resume_1138.txt
# Found duplicate for filename: resume_1234.txt
# Found duplicate for filename: resume_1106.txt
# Found duplicate for filename: resume_1067.txt
# Found duplicate for filename: resume_1112.txt
# Found duplicate for filename: resume_1164.txt
# Found duplicate for filename: resume_1189.txt
# Found duplicate for filename: resume_1168.txt
# Found duplicate for filename: resume_1388.txt
# Found duplicate for filename: resume_106.txt
# Found duplicate for filename: resume_1054.txt
# Found duplicate for filename: resume_1031.txt
# Found duplicate for filename: resume_118.txt
# Found duplicate for filename: resume_1002.txt
# Found duplicate for filename: resume_1172.txt
# Found duplicate for filename: resume_1314.txt
# Found duplicate for filename: resume_1076.txt
# Found duplicate for filename: resume_104.txt
# Found duplicate for filename: resume_1083.txt
# Found 447 duplicates to delete
# Successfully deleted 447 duplicates from storyteller
